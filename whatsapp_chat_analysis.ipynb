# %%
import re
import pandas as pd

# %%
f = open("D:\e\Sem6\whatspp_chat_analysis\WhatsApp Chat with HELP  FORUM.txt","r",encoding = 'utf-8')

# %%
data = f.read()

# %%
print(data)
# Out:
# 17/10/2020, 20:08 - +1 (416) 617-1084 created group "HELP  FORUM"
# 17/10/2020, 20:08 - You were added
# 28/08/2021, 01:11 - +1 (647) 679-5993: Amrit Centennial 🇨🇦.vcf (file attached)
# 28/08/2021, 01:11 - +1 (647) 679-5993: Hi Prashant, can you please add him to this group
# 28/08/2021, 07:04 - +1 (416) 617-1084: Will do
# 28/08/2021, 07:04 - +1 (416) 617-1084 added +1 (416) 602-1705
# 28/08/2021, 07:25 - +1 (647) 679-5993: Shukriya 👍🏻
# 28/08/2021, 08:21 - +1 (416) 617-1084: No worries
# 29/08/2021, 21:48 - +1 (647) 539-7875: Hi everyone,
#
# We are hiring part- time and full time for restaurant help. The restaurant are in Stoney creek,Hamilton. PR support with be provided.If you are interested then contact me on 647-539-7875.
#
# Thank you
# Mayur
# 29/08/2021, 22:20 - +1 (647) 469-9351: Monal.vcf (file attached)
# 29/08/2021, 22:20 - +1 (647) 469-9351: Hey Admin!
# Can you please add this number
# 29/08/2021, 22:59 - +1 (416) 617-1084: Alright
# ...

# %%
pattern = '\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'

# %%
messages = re.split(pattern,data)[1:]
messages
# Out:
# ['+1 (416) 617-1084 created group "HELP  FORUM"\n',
#  'You were added\n',
#  '+1 (647) 679-5993: Amrit Centennial 🇨🇦.vcf (file attached)\n',
#  '+1 (647) 679-5993: Hi Prashant, can you please add him to this group\n',
#  '+1 (416) 617-1084: Will do\n',
#  '+1 (416) 617-1084 added +1 (416) 602-1705\n',
#  '+1 (647) 679-5993: Shukriya 👍🏻\n',
#  '+1 (416) 617-1084: No worries\n',
#  '+1 (647) 539-7875: Hi everyone,\n\nWe are hiring part- time and full time for restaurant help. The restaurant are in Stoney creek,Hamilton. PR support with be provided.If you are interested then contact me on 647-539-7875.\n\nThank you\nMayur\n',
#  '+1 (647) 469-9351: Monal.vcf (file attached)\n',
#  '+1 (647) 469-9351: Hey Admin!\nCan you please add this number\n',
#  '+1 (416) 617-1084: Alright\n',
#  '+1 (416) 617-1084 added +1 (416) 230-8278\n',
#  '+1 (647) 469-9351: Thank you\n',
#  'Sanket Shah: <Media omitted>\n',
#  'Sanket Shah: <Media omitted>\n',
# ...

# %%
dates = re.findall(pattern,data)
dates
# Out:
# ['17/10/2020, 20:08 - ',
#  '17/10/2020, 20:08 - ',
#  '28/08/2021, 01:11 - ',
#  '28/08/2021, 01:11 - ',
#  '28/08/2021, 07:04 - ',
#  '28/08/2021, 07:04 - ',
#  '28/08/2021, 07:25 - ',
#  '28/08/2021, 08:21 - ',
#  '29/08/2021, 21:48 - ',
#  '29/08/2021, 22:20 - ',
#  '29/08/2021, 22:20 - ',
#  '29/08/2021, 22:59 - ',
#  '29/08/2021, 22:59 - ',
#  '30/08/2021, 11:23 - ',
#  '30/08/2021, 12:09 - ',
#  '30/08/2021, 12:09 - ',
#  '30/08/2021, 12:10 - ',
#  '30/08/2021, 16:55 - ',
#  '30/08/2021, 18:13 - ',
#  '30/08/2021, 18:29 - ',
#  '30/08/2021, 19:45 - ',
#  '30/08/2021, 19:46 - ',
#  '30/08/2021, 19:47 - ',
#  '30/08/2021, 19:47 - ',
#  '30/08/2021, 19:48 - ',
#  '30/08/2021, 19:48 - ',
#  '30/08/2021, 19:49 - ',
#  '30/08/2021, 19:49 - ',
#  '30/08/2021, 20:13 - ',
#  '30/08/2021, 20:13 - ',
#  '30/08/2021, 21:59 - ',
#  '30/08/2021, 22:29 - ',
#  '31/08/2021, 05:37 - ',
#  '31/08/2021, 09:17 - ',
#  '31/08/2021, 09:50 - ',
#  '31/08/2021, 11:59 - ',
#  '01/09/2021, 11:08 - ',
# ...

# %%
df = pd.DataFrame({'user_message' : messages, 'message_date' : dates})

df['message_date'] = pd.to_datetime(df['message_date'], format = '%d/%m/%Y, %H:%M - ')
df.rename(columns = {'message_date' : 'date'},inplace = True)
df.head()
# Out:
#                                         user_message                date
# 0    +1 (416) 617-1084 created group "HELP  FORUM"\n 2020-10-17 20:08:00
# 1                                   You were added\n 2020-10-17 20:08:00
# 2  +1 (647) 679-5993: Amrit Centennial 🇨🇦.vcf (fi... 2021-08-28 01:11:00
# 3  +1 (647) 679-5993: Hi Prashant, can you please... 2021-08-28 01:11:00
# 4                       +1 (416) 617-1084: Will do\n 2021-08-28 07:04:00

# %%
df.shape
# Out:
# (443, 2)

# %%
# separate user and message
users = []
messages = []

for message in df['user_message']:
    entry = re.split('([\w\W]+?):\s',message)
    if entry[1:]: #username
        users.append(entry[1])
        messages.append(entry[2])
    else:
        users.append('group_notifications')
        messages.append(entry[0])
        
df['user'] = users
df['message'] = messages
df.drop(columns = ['user_message'],inplace = True)
df.head()
# Out:
#                  date                 user  \
# 0 2020-10-17 20:08:00  group_notifications
# 1 2020-10-17 20:08:00  group_notifications
# 2 2021-08-28 01:11:00    +1 (647) 679-5993
# 3 2021-08-28 01:11:00    +1 (647) 679-5993
# 4 2021-08-28 07:04:00    +1 (416) 617-1084
#
#                                              message
# 0    +1 (416) 617-1084 created group "HELP  FORUM"\n
# 1                                   You were added\n
# 2          Amrit Centennial 🇨🇦.vcf (file attached)\n
# 3  Hi Prashant, can you please add him to this gr...
# 4                                          Will do\n

# %%
df['year'] = df['date'].dt.year

# %%
df.head()
# Out:
#                  date                 user  \
# 0 2020-10-17 20:08:00  group_notifications
# 1 2020-10-17 20:08:00  group_notifications
# 2 2021-08-28 01:11:00    +1 (647) 679-5993
# 3 2021-08-28 01:11:00    +1 (647) 679-5993
# 4 2021-08-28 07:04:00    +1 (416) 617-1084
#
#                                              message  year
# 0    +1 (416) 617-1084 created group "HELP  FORUM"\n  2020
# 1                                   You were added\n  2020
# 2          Amrit Centennial 🇨🇦.vcf (file attached)\n  2021
# 3  Hi Prashant, can you please add him to this gr...  2021
# 4                                          Will do\n  2021

# %%
df['month'] = df['date'].dt.month_name()

# %%
df.head()
# Out:
#                  date                 user  \
# 0 2020-10-17 20:08:00  group_notifications
# 1 2020-10-17 20:08:00  group_notifications
# 2 2021-08-28 01:11:00    +1 (647) 679-5993
# 3 2021-08-28 01:11:00    +1 (647) 679-5993
# 4 2021-08-28 07:04:00    +1 (416) 617-1084
#
#                                              message  year    month
# 0    +1 (416) 617-1084 created group "HELP  FORUM"\n  2020  October
# 1                                   You were added\n  2020  October
# 2          Amrit Centennial 🇨🇦.vcf (file attached)\n  2021   August
# 3  Hi Prashant, can you please add him to this gr...  2021   August
# 4                                          Will do\n  2021   August

# %%
df['day'] = df['date'].dt.day

# %%
df['hour'] = df['date'].dt.hour

# %%
df['minute'] = df['date'].dt.minute

# %%
df.head()
# Out:
#                  date                 user  \
# 0 2020-10-17 20:08:00  group_notifications
# 1 2020-10-17 20:08:00  group_notifications
# 2 2021-08-28 01:11:00    +1 (647) 679-5993
# 3 2021-08-28 01:11:00    +1 (647) 679-5993
# 4 2021-08-28 07:04:00    +1 (416) 617-1084
#
#                                              message  year    month  day  \
# 0    +1 (416) 617-1084 created group "HELP  FORUM"\n  2020  October   17
# 1                                   You were added\n  2020  October   17
# 2          Amrit Centennial 🇨🇦.vcf (file attached)\n  2021   August   28
# 3  Hi Prashant, can you please add him to this gr...  2021   August   28
# 4                                          Will do\n  2021   August   28
#
#    hour  minute
# 0    20       8
# 1    20       8
# 2     1      11
# 3     1      11
# 4     7       4

# %%
words =[]
for message in df['message']:
    words.extend(message.split())

# %%
len(words)
# Out:
# 4997

# %%
from urlextract import URLExtract

extract = URLExtract()

# %%
links = []
for message in df['message']:
    links.extend(extract.find_urls(message))

# %%
x = df['user'].value_counts().head()

# %%
import matplotlib.pyplot as plt

# %%
name = x.index
count = x.values

# %%
plt.bar(name,count)
plt.xticks(rotation = 'vertical')
plt.show()

# %%
# finding out percentage of message by per user in group
round((df['user'].value_counts()/df.shape[0])*100,2).reset_index().rename(columns = {'index':'name','user':'percentage'})
# Out:
#                    name  percentage
# 0   group_notifications       32.96
# 1     +1 (437) 248-6874       10.16
# 2     +1 (416) 617-1084        8.58
# 3     +1 (647) 640-6032        7.90
# 4           Sanket Shah        3.84
# ..                  ...         ...
# 61    +1 (905) 809-7057        0.23
# 62    +1 (647) 906-5550        0.23
# 63    +1 (647) 971-7648        0.23
# 64    +1 (647) 878-9958        0.23
# 65    +1 (437) 237-7430        0.23
#
# [66 rows x 2 columns]

# %%
temp = df[df['user'] != 'group_notifications'] # remove group notifications
temp = temp[df['message'] != '<Media omitted>\n'] # remove media omitted
# Out:
# <ipython-input-33-0f20c060e14d>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp = temp[df['message'] != '<Media omitted>\n'] # remove media omitted

# %%
words = []
for message in temp['message']:
    for word in message.lower().split():
        words.append(word)

# %%
from collections import Counter
pd.DataFrame(Counter(words).most_common(20))
# Out:
#             0    1
# 0         for  118
# 1          in   80
# 2          to   63
# 3         and   57
# 4      please   53
# 5          is   45
# 6           a   43
# 7          if   42
# 8         you   41
# 9          or   41
# 10    looking   36
# 11          -   35
# 12     hiring   34
# 13        the   32
# 14        are   28
# 15         me   28
# 16  available   28
# 17        any   28
# 18          i   26
# 19        can   25

# %%
# !pip install emoji

# %%
import emoji

# %%
'''emojis = []
for message in df['message']:
    emojis = emoji.distinct_emoji_list(message)
    print(emojis)'''
    #emojis.extend(emoji.demojize(is_emoji) for is_emoji in emojis)
# Out:
# "emojis = []\nfor message in df['message']:\n    emojis = emoji.distinct_emoji_list(message)\n    print(emojis)"

# %%
emojis = []
for message in df['message']:
    emojis.extend([c for c in message if c in emoji.UNICODE_EMOJI['en']])

# %%
pd.DataFrame(Counter(emojis).most_common(len(Counter(emojis))))
# Out:
#     0  1
# 0   🏡  3
# 1   🏠  3
# 2   📍  3
# 3   🗓  3
# 4   🍽  3
# 5   👍  2
# 6   🏻  2
# 7   🤣  2
# 8   🙏  2
# 9   😊  2
# 10  🏼  1
# 11  🙂  1
# 12  🐂  1
# 13  🔥  1
# 14  🐕  1

# %%
df['month_num'] = df['date'].dt.month

# %%
timeline = df.groupby(['year','month_num','month']).count()['message'].reset_index()

# %%
timeline
# Out:
#     year  month_num      month  message
# 0   2020         10    October        2
# 1   2021          8     August       34
# 2   2021          9  September      118
# 3   2021         10    October       37
# 4   2021         11   November       28
# 5   2021         12   December       11
# 6   2022          1    January        8
# 7   2022          2   February       10
# 8   2022          3      March        9
# 9   2022          4      April        6
# 10  2022          5        May       32
# 11  2022          6       June       58
# 12  2022          7       July       80
# 13  2022          8     August       10

# %%
time = []
for i in range(timeline.shape[0]):
    time.append(timeline['month'][i] + "-" + str(timeline['year'][i]))

# %%
timeline['time'] = time

# %%
timeline
# Out:
#     year  month_num      month  message            time
# 0   2020         10    October        2    October-2020
# 1   2021          8     August       34     August-2021
# 2   2021          9  September      118  September-2021
# 3   2021         10    October       37    October-2021
# 4   2021         11   November       28   November-2021
# 5   2021         12   December       11   December-2021
# 6   2022          1    January        8    January-2022
# 7   2022          2   February       10   February-2022
# 8   2022          3      March        9      March-2022
# 9   2022          4      April        6      April-2022
# 10  2022          5        May       32        May-2022
# 11  2022          6       June       58       June-2022
# 12  2022          7       July       80       July-2022
# 13  2022          8     August       10     August-2022

# %%
plt.plot(timeline['time'],timeline['message'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['only_date'] = df['date'].dt.date

# %%
daily_timeline = df.groupby('only_date').count()['message'].reset_index()

# %%
plt.figure(figsize=(18,10))
plt.plot(daily_timeline['only_date'],daily_timeline['message'])

# %%
df['day_name'] = df['date'].dt.day_name()

# %%
df['day_name'].value_counts()
# Out:
# Tuesday      92
# Thursday     84
# Monday       73
# Wednesday    70
# Friday       51
# Sunday       40
# Saturday     33
# Name: day_name, dtype: int64

# %%
period = []
for hour in df[['day_name', 'hour']]['hour']:
    if hour == 23:
        period.append(str(hour) + "-" + str('00'))
    elif hour == 0:
        period.append(str('00') + "-" + str(hour+1))
    else:
        period.append(str(hour) + "-" + str(hour+1))

# %%
df['period'] = period

# %%
df.sample(5)
# Out:
#                    date                 user  \
# 43  2021-09-01 23:03:00      +91 82888 38248
# 81  2021-09-16 20:53:00    +1 (647) 702-9805
# 310 2022-06-14 18:22:00    +1 (647) 640-6032
# 399 2022-07-19 10:32:00    +1 (437) 248-6874
# 0   2020-10-17 20:08:00  group_notifications
#
#                                                message  year      month  day  \
# 43                           Okay. Thank you so much\n  2021  September    1
# 81   Hi everyone,\nAvailable sharing space for Guja...  2021  September   16
# 310                                                     2022       June   14
# 399                                  <Media omitted>\n  2022       July   19
# 0      +1 (416) 617-1084 created group "HELP  FORUM"\n  2020    October   17
#
#      hour  minute  month_num   only_date   day_name period
# 43     23       3          9  2021-09-01  Wednesday  23-00
# 81     20      53          9  2021-09-16   Thursday  20-21
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20,6))
sns.heatmap(df.pivot_table(index='day_name',columns = 'period',values='message',aggfunc='count').fillna(0))
plt.yticks(rotation='horizontal')
plt.show()

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
sent = SentimentIntensityAnalyzer()

# %%
df['scores'] = df['message'].apply(lambda message: sent.polarity_scores(message))
df.head()
# Out:
#                  date                 user  \
# 0 2020-10-17 20:08:00  group_notifications
# 1 2020-10-17 20:08:00  group_notifications
# 2 2021-08-28 01:11:00    +1 (647) 679-5993
# 3 2021-08-28 01:11:00    +1 (647) 679-5993
# 4 2021-08-28 07:04:00    +1 (416) 617-1084
#
#                                              message  year    month  day  \
# 0    +1 (416) 617-1084 created group "HELP  FORUM"\n  2020  October   17
# 1                                   You were added\n  2020  October   17
# 2          Amrit Centennial 🇨🇦.vcf (file attached)\n  2021   August   28
# 3  Hi Prashant, can you please add him to this gr...  2021   August   28
# 4                                          Will do\n  2021   August   28
#
#    hour  minute  month_num   only_date  day_name period  sentiment_score  \
# 0    20       8         10  2020-10-17  Saturday  20-21             0.66
# 1    20       8         10  2020-10-17  Saturday  20-21             0.00
# ...

# %%
df['compound'] = df['scores'].apply(lambda score_dict: score_dict['compound'])
df['sentiment_type']=''
df.loc[df.compound>0,'sentiment_type']='Positive'
df.loc[df.compound==0,'sentiment_type']='Neutral'
df.loc[df.compound<0,'sentiment_type']='Negative'
df
# Out:
#                    date                 user  \
# 0   2020-10-17 20:08:00  group_notifications
# 1   2020-10-17 20:08:00  group_notifications
# 2   2021-08-28 01:11:00    +1 (647) 679-5993
# 3   2021-08-28 01:11:00    +1 (647) 679-5993
# 4   2021-08-28 07:04:00    +1 (416) 617-1084
# ..                  ...                  ...
# 438 2022-08-19 10:52:00  group_notifications
# 439 2022-08-20 20:15:00    +1 (647) 673-5520
# 440 2022-08-22 09:27:00  group_notifications
# 441 2022-08-22 09:32:00  group_notifications
# 442 2022-08-22 11:04:00          Sanket Shah
#
#                                                message  year    month  day  \
# 0      +1 (416) 617-1084 created group "HELP  FORUM"\n  2020  October   17
# 1                                     You were added\n  2020  October   17
# 2            Amrit Centennial 🇨🇦.vcf (file attached)\n  2021   August   28
# 3    Hi Prashant, can you please add him to this gr...  2021   August   28
# ...

# %%
df['sentiment_type'].value_counts().index[0]
# Out:
# You have selected 0      group_notifications
# 1      group_notifications
# 2        +1 (647) 679-5993
# 3        +1 (647) 679-5993
# 4        +1 (416) 617-1084
#               ...
# 438    group_notifications
# 439      +1 (647) 673-5520
# 440    group_notifications
# 441    group_notifications
# 442            Sanket Shah
# Name: user, Length: 443, dtype: object to check sentiment analysis type
